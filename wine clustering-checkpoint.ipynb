# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style='darkgrid', font_scale=1.4)

# %%
data=pd.read_csv('wine-clustering.csv')
data
# Out:
#      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0      14.23        1.71  2.43          15.6        127           2.80
# 1      13.20        1.78  2.14          11.2        100           2.65
# 2      13.16        2.36  2.67          18.6        101           2.80
# 3      14.37        1.95  2.50          16.8        113           3.85
# 4      13.24        2.59  2.87          21.0        118           2.80
# ..       ...         ...   ...           ...        ...            ...
# 173    13.71        5.65  2.45          20.5         95           1.68
# 174    13.40        3.91  2.48          23.0        102           1.80
# 175    13.27        4.28  2.26          20.0        120           1.59
# 176    13.17        2.59  2.37          20.0        120           1.65
# 177    14.13        4.10  2.74          24.5         96           2.05
#
#      Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# ...

# %%
data.isna().sum().sum()
# Out:
# 0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Alcohol               178 non-null    float64
#  1   Malic_Acid            178 non-null    float64
#  2   Ash                   178 non-null    float64
#  3   Ash_Alcanity          178 non-null    float64
#  4   Magnesium             178 non-null    int64
#  5   Total_Phenols         178 non-null    float64
#  6   Flavanoids            178 non-null    float64
#  7   Nonflavanoid_Phenols  178 non-null    float64
#  8   Proanthocyanins       178 non-null    float64
#  9   Color_Intensity       178 non-null    float64
#  10  Hue                   178 non-null    float64
#  11  OD280                 178 non-null    float64
#  12  Proline               178 non-null    int64
# dtypes: float64(11), int64(2)
# memory usage: 18.2 KB

# %%
data.describe()
# Out:
#           Alcohol  Malic_Acid         Ash  Ash_Alcanity   Magnesium  \
# count  178.000000  178.000000  178.000000    178.000000  178.000000
# mean    13.000618    2.336348    2.366517     19.494944   99.741573
# std      0.811827    1.117146    0.274344      3.339564   14.282484
# min     11.030000    0.740000    1.360000     10.600000   70.000000
# 25%     12.362500    1.602500    2.210000     17.200000   88.000000
# 50%     13.050000    1.865000    2.360000     19.500000   98.000000
# 75%     13.677500    3.082500    2.557500     21.500000  107.000000
# max     14.830000    5.800000    3.230000     30.000000  162.000000
#
#        Total_Phenols  Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...

# %%
data.corr()
# Out:
#                        Alcohol  Malic_Acid       Ash  Ash_Alcanity  Magnesium  \
# Alcohol               1.000000    0.094397  0.211545     -0.310235   0.270798
# Malic_Acid            0.094397    1.000000  0.164045      0.288500  -0.054575
# Ash                   0.211545    0.164045  1.000000      0.443367   0.286587
# Ash_Alcanity         -0.310235    0.288500  0.443367      1.000000  -0.083333
# Magnesium             0.270798   -0.054575  0.286587     -0.083333   1.000000
# Total_Phenols         0.289101   -0.335167  0.128980     -0.321113   0.214401
# Flavanoids            0.236815   -0.411007  0.115077     -0.351370   0.195784
# Nonflavanoid_Phenols -0.155929    0.292977  0.186230      0.361922  -0.256294
# Proanthocyanins       0.136698   -0.220746  0.009652     -0.197327   0.236441
# Color_Intensity       0.546364    0.248985  0.258887      0.018732   0.199950
# Hue                  -0.071747   -0.561296 -0.074667     -0.273955   0.055398
# ...

# %%
X=data[["Alcohol","Malic_Acid"]]
X
# Out:
#      Alcohol  Malic_Acid
# 0      14.23        1.71
# 1      13.20        1.78
# 2      13.16        2.36
# 3      14.37        1.95
# 4      13.24        2.59
# ..       ...         ...
# 173    13.71        5.65
# 174    13.40        3.91
# 175    13.27        4.28
# 176    13.17        2.59
# 177    14.13        4.10
#
# [178 rows x 2 columns]

# %%
#Scatterplot of X
plt.figure(figsize=(10,6))
sns.scatterplot(x = 'Alcohol',y = 'Malic_Acid',  data = X  ,s = 60 )
plt.xlabel('Alcohol')
plt.ylabel('Malic_Acid') 
plt.title('Malic_Acid vs Alcohol')
plt.show()

# %%
#Importing KMeans from sklearn
from sklearn.cluster import KMeans

# %%
wcss=[]
for i in range(1,11):
    km=KMeans(n_clusters=i)
    km.fit(X)
    wcss.append(km.inertia_)
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
#The elbow curve
plt.figure(figsize=(12,6))
plt.plot(range(1,11),wcss)
plt.plot(range(1,11),wcss, linewidth=2, color="red", marker ="8")
plt.xlabel("K Value")
plt.xticks(np.arange(1,11,1))
plt.ylabel("WCSS")
plt.show()

# %%
#Taking 5 clusters
km1=KMeans(n_clusters=5)
#Fitting the input data
km1.fit(X)
#predicting the labels of the input data
y=km1.predict(X)
#adding the labels to a column named label
X["label"] = y
#The new dataframe with the clustering done
X.head()
# Out:
# C:\Users\Dell\AppData\Local\Temp/ipykernel_13972/1657950751.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["label"] = y
#    Alcohol  Malic_Acid  label
# 0    14.23        1.71      0
# 1    13.20        1.78      0
# 2    13.16        2.36      4
# 3    14.37        1.95      0
# 4    13.24        2.59      4

# %%
#Scatterplot of the clusters
plt.figure(figsize=(10,6))
sns.scatterplot(x = 'Alcohol',y = 'Malic_Acid',hue="label",  
                 palette=['green','orange','brown','dodgerblue','red'], legend='full',data = X  ,s = 60 )
plt.xlabel('Alcohol')
plt.ylabel('Malic_Acid') 
plt.title('malic_acid vs alcohol')
plt.show()

# %%
Y=data[["Total_Phenols","Color_Intensity"]]
Y
# Out:
#      Total_Phenols  Color_Intensity
# 0             2.80             5.64
# 1             2.65             4.38
# 2             2.80             5.68
# 3             3.85             7.80
# 4             2.80             4.32
# ..             ...              ...
# 173           1.68             7.70
# 174           1.80             7.30
# 175           1.59            10.20
# 176           1.65             9.30
# 177           2.05             9.20
#
# [178 rows x 2 columns]

# %%
#Scatterplot of X
plt.figure(figsize=(10,6))
sns.scatterplot(x = 'Total_Phenols',y = 'Color_Intensity',  data = Y  ,s = 60 )
plt.xlabel('Total_Phenols')
plt.ylabel('Color_Intensity') 
plt.title('Color_Intensity vs Total_Phenols')
plt.show()

# %%
#Importing KMeans from sklearn
from sklearn.cluster import KMeans

# %%
wcss=[]
for i in range(1,11):
    km=KMeans(n_clusters=i)
    km.fit(Y)
    wcss.append(km.inertia_)
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
#The elbow curve
plt.figure(figsize=(12,6))
plt.plot(range(1,11),wcss)
plt.plot(range(1,11),wcss, linewidth=2, color="red", marker ="8")
plt.xlabel("K Value")
plt.xticks(np.arange(1,11,1))
plt.ylabel("WCSS")
plt.show()

# %%
#Taking 5 clusters
km1=KMeans(n_clusters=5)
#Fitting the input data
km1.fit(Y)
#predicting the labels of the input data
y=km1.predict(Y)
#adding the labels to a column named label
Y["label"] = y
#The new dataframe with the clustering done
Y.head()
# Out:
# C:\Users\Dell\AppData\Local\Temp/ipykernel_13972/1327495888.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y["label"] = y
#    Total_Phenols  Color_Intensity  label
# 0           2.80             5.64      2
# 1           2.65             4.38      4
# 2           2.80             5.68      2
# 3           3.85             7.80      1
# 4           2.80             4.32      4

# %%
#Scatterplot of the clusters
plt.figure(figsize=(10,6))
sns.scatterplot(x = 'Total_Phenols',y = 'Color_Intensity',hue="label",  
                 palette=['green','orange','brown','dodgerblue','red'], legend='full',data = Y ,s = 60 )
plt.xlabel('Total_Phenols')
plt.ylabel('Color_Intensity') 
plt.title('Color_Intensity vs Total_Phenols')
plt.show()
